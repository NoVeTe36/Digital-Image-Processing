# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Part 2

# %% [markdown]
# Task 1: Import gray scale image

# %%
grayscale = cv2.imread('grayscale.jpg')
plt.imshow(grayscale)

# %% [markdown]
# Task 2: Resize image

# %%
grayscale_resize = cv2.resize(grayscale, (0,0), fx=0.3, fy=0.3)
plt.imshow(grayscale_resize)

# %% [markdown]
# Task 3: Change brightness

# %%
modified = grayscale.copy()
for i in range(0, modified.shape[0]):
    for j in range(0, modified.shape[1]):
        modified[i][j] =  0.5 * modified[i][j] + 10

row, col, ch = grayscale.shape
fig, axs = plt.subplots(1, 2, figsize=(15, 15))
fig.tight_layout()
axs[0].imshow(cv2.cvtColor(grayscale, cv2.COLOR_BGR2RGB))
axs[0].set_title('Original Image')
axs[1].imshow(cv2.cvtColor(modified, cv2.COLOR_BGR2RGB))
axs[1].set_title('Modiied Brightness')
plt.show()

# %% [markdown]
# Task 4: Histogram equalization

# %%
cv2.calcHist([grayscale], [0], None, [256], [0, 256])
plt.hist(grayscale.ravel(), 256, [0, 256])
plt.title('Histogram for grayscale image')
plt.xlabel('Intensity Value')
plt.ylabel('Pixel Count')
plt.show()

# %%
grayscale_fixed = grayscale.copy()
grayscale_fixed = cv2.cvtColor(grayscale_fixed, cv2.COLOR_BGR2GRAY)
grayscale_fixed = cv2.equalizeHist(grayscale_fixed)
plt.hist(grayscale_fixed.ravel(), 256, [0, 256])
plt.title('Histogram for grayscale image')
plt.xlabel('Intensity Value')
plt.ylabel('Pixel Count')
plt.show()

# %%
fig, axs = plt.subplots(1, 2, figsize=(15, 15))
fig.tight_layout()
axs[0].imshow(cv2.cvtColor(grayscale, cv2.COLOR_BGR2RGB))
axs[0].set_title('Original Image')
axs[1].imshow(cv2.cvtColor(grayscale_fixed, cv2.COLOR_BGR2RGB))
axs[1].set_title('Equalized Histogram')
plt.show()

# %% [markdown]
# Task 5: Image Thresholds

# %%
plt.imshow(cv2.cvtColor(grayscale_fixed, cv2.COLOR_BGR2RGB))
ret, thresh = cv2.threshold(grayscale_fixed, 127, 255, cv2.THRESH_BINARY)
plt.imshow(cv2.cvtColor(thresh, cv2.COLOR_BGR2RGB))
